# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     Age     Sex  Weight  Height  SystolicBP  DiastolicBP  TotalCholesterol  \
# 0    38    Male      78    1.80         122           80               190
# 1    44  Female      61    1.63         128           72               165
# 2    57    Male      89    1.78         138           88               225
# 3    23  Female      57    1.57         116           64               200
# 4    52  Female      67    1.65         128           76               195
# 5    48    Male      81    1.74         129           80               215
# 6    36  Female      60    1.60         118           70               180
# 7    66    Male      77    1.67         144           92               220
# 8    39  Female      72    1.70         123           76               190
# 9    57    Male      94    1.86         140           86               240
# 10   33    Male      73    1.75         126           78               185
#
#     HDLCholesterol  History  HandgripStrength
# ...

# %%
df = pd.read_excel('rawdata.xlsx')

# %%
df
# Out:
#      Testperson (number)  Gender (M/F)  Age (years)  Medicin (n)  \
# 0                      1             1           84          8.0
# 1                      2             2           37          1.0
# 2                      3             2           62          0.0
# 3                      4             2           85          4.0
# 4                      5             1           73          5.0
# ..                   ...           ...          ...          ...
# 349                  351             1           70          2.0
# 350                  352             2           23          0.0
# 351                  353             1           55          0.0
# 352                  354             2           93          1.0
# 353                  355             2           81          2.0
#
#     Smokingstatus (Yes=1, No=2, previously=3)  Packyears  \
# 0                                           3       18.0
# 1                                           2        NaN
# ...

# %%
df
# Out:
#      Testperson (number)  Gender (M/F)  Age (years)  Medicin (n)  \
# 0                      1             1           84          8.0
# 1                      2             2           37          1.0
# 2                      3             2           62          0.0
# 3                      4             2           85          4.0
# 4                      5             1           73          5.0
# ..                   ...           ...          ...          ...
# 349                  351             1           70          2.0
# 350                  352             2           23          0.0
# 351                  353             1           55          0.0
# 352                  354             2           93          1.0
# 353                  355             2           81          2.0
#
#     Smokingstatus (Yes=1, No=2, previously=3)  Packyears  \
# 0                                           3       18.0
# 1                                           2        NaN
# ...

# %%
# get mean of all the columns median standard deviation and variance
df1 =df.describe()

# %%
# transfrom
df1 = df1.transpose()

# %%
df1
# Out:
#                                count        mean         std         min  \
# Testperson (number)            354.0  177.867232  102.738629    1.000000
# Gender (M/F)                   354.0    1.593220    0.491928    1.000000
# Age (years)                    354.0   55.096045   20.800192   20.000000
# Medicin (n)                    267.0    1.782772    2.359910    0.000000
# Packyears                      234.0   10.452991   14.830441    0.000000
# Activitylevel work (1-4)       222.0    2.009009    0.970100    0.000000
# Activitylevel sparetime (1-4)  346.0    2.575145    0.828035    1.000000
# B1SD                           238.0   47.140028   16.569882   19.880834
# B1SND                          238.0   46.978021   16.460313   20.687702
# B1EAD                          238.0  156.278554   70.270031   45.936049
# B1EAND                         238.0  157.339192   89.574133   44.700064
# B2BS                           353.0   13.256828    5.413980    5.874291
# ...

# %%
# save to csv
df1.to_csv('data1.csv')
